# %% [markdown]
# # Baseline RAG
# - Query all retrievers (hybrid), concatenate context, call LLM
# - Measure latency and cost per query

# %%
import sys
sys.path.insert(0, "..")
from src.rag import baseline_retrieve
# results = baseline_retrieve("What is the refund policy?", ["general", "technical"], top_k_per=5)
