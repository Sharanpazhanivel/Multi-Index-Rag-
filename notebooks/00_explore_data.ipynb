# %% [markdown]
# # Explore data and indexes
# - Inspect `data/raw` and `data/processed`
# - Check chunk stats and index coverage

# %%
from pathlib import Path
ROOT = Path("..")
# TODO: list data/raw, data/processed; load sample chunks
